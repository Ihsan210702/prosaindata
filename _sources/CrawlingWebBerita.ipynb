# %% [markdown]
# # CRAWLING  WEBSITE BERITA
# Website yang diambil untuk crawling yaitu https://www.goal.com/
#
# ---

# %% [markdown]
# ## 1. Install modul Beautifulsoup dan requests

# %%
# !pip install requests
# !pip install BeautifulSoup4
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (2.25.1)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests) (2022.12.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests) (2.10)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: BeautifulSoup4 in /usr/local/lib/python3.8/dist-packages (4.6.3)

# %% [markdown]
# ## 2. Import library

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# ## 3. Peroses crawling menggunakan bs4 dan request

# %%
#Inisialisasi Link URL
url = 'https://www.goal.com/id/berita/'

headers={
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/110.0.0.0 Safari/537.36'
    }

#inisialisasi list untuk memasukkan hasil crawling kedalam list
listJudul = []
listIsi = []

#proses perulangan untuk crawling data
for page in range(1,4):
  req = requests.get(url+str(page), headers=headers)
  soup = BeautifulSoup(req.text, 'html.parser')
  items = soup.findAll('article')
  for it in items:
    try: link = it.find('a')['href']
    except : link=''
    try: title = it.find('h3', 'title h5').text 
    except : title=''
    
    if title != '':
      listJudul.append(title)

    if link != '':
      req2 = requests.get("https://www.goal.com/"+str(link), headers=headers)
      soup2 = BeautifulSoup(req2.text, 'html.parser')
      items2 = soup2.findAll("div", "article-body_body__JAkqy body")
      for it2 in items2:
        try : berita = it2.find('p').text
        except : berita=''

        if berita != '':
          listIsi.append(berita)


df_Judul = pd.DataFrame(listJudul, columns=["Judul Berita"])
df_Isi = pd.DataFrame(listIsi, columns=["Isi Berita"])

data = pd.concat([df_Judul, df_Isi], axis=1)
data = data.loc[0:50]
data
# Out:
#                                          Judul Berita  \
# 0             Arsenal Resmi Ajukan Tawaran Untuk Rice
# 1   Ini Alasan Jorginho Tinggalkan Chelsea & Membe...
# 2   Indonesia Masih Debat, Vietnam Justru Sibuk Si...
# 3        Ferdinand Tak Yakin Kane Bakal Gabung United
# 4   “Tergantung Napoli” - Respons Osimhen Dilirik ...
# 5   Gakpo: Target Liverpool Cetak Banyak Gol Ke Ga...
# 6   Werner: Saya Dilupakan Tuchel & Lukaku Jadi Ma...
# 7   'Perampokan Terbesar!' - Casillas Kecam Barca ...
# 8   "Seperti Main Sepuluh Orang Doang" - Kritik Pe...
# 9   PSG Mau 'CLBK' Dengan Tuchel, Dulu Keliru Meme...
# 10  Duel Persib Kontra Arema Digelar Di Pakansari ...
# 11  Pertemuan Klub Berubah Menjadi Mobilisasi Mela...
# 12  Tak Sabar Duel Di UCL, Ancelotti: Madrid & Liv...
# 13  Masa Depan Messi Di PSG Tak Jelas, Bagaimana D...
# 14  Klopp Melongo! Jurnalis Ajukan Pertanyaan "Sin...
# 15  Luka Modric: Kasus Saya & Jude Bellingham Berbeda
# 16  Rashford 'Kesurupan' Ronaldo, Selevel Kylian M...
# 17  Liverpool vs Real Madrid: Live Streaming & Kab...
