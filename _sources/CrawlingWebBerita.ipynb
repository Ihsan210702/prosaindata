# %% [markdown]
# # CRAWLING  WEBSITE BERITA
# Website yang diambil untuk crawling yaitu https://www.goal.com/
#
# ---

# %% [markdown]
# ## 1. Install modul Beautifulsoup dan requests

# %%
# !pip install requests
# !pip install BeautifulSoup4
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (2.25.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests) (1.26.14)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests) (2.10)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: BeautifulSoup4 in /usr/local/lib/python3.8/dist-packages (4.6.3)

# %% [markdown]
# ## 2. Import library

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# ## 3. Peroses crawling menggunakan bs4 dan request

# %%
#Inisialisasi Link URL
url = 'https://www.goal.com/id/berita/'

headers={
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/110.0.0.0 Safari/537.36'
    }

#inisialisasi list untuk memasukkan hasil crawling kedalam list
listJudul = []
listIsi = []

#proses perulangan untuk crawling data
for page in range(1,4):
  req = requests.get(url+str(page), headers=headers)
  soup = BeautifulSoup(req.text, 'html.parser')
  items = soup.findAll('article')
  for it in items:
    try: link = it.find('a')['href']
    except : link=''
    try: title = it.find('h3', 'title h5').text 
    except : title=''
    
    if title != '':
      listJudul.append(title)

    if link != '':
      req2 = requests.get("https://www.goal.com/"+str(link), headers=headers)
      soup2 = BeautifulSoup(req2.text, 'html.parser')
      items2 = soup2.findAll("div", "article-body_body__JAkqy body")
      for it2 in items2:
        try : berita = it2.find('p').text
        except : berita=''

        if berita != '':
          listIsi.append(berita)


df_Judul = pd.DataFrame(listJudul, columns=["Judul Berita"])
df_Isi = pd.DataFrame(listIsi, columns=["Isi Berita"])

data = pd.concat([df_Judul, df_Isi], axis=1)
data = data.loc[0:50]
data
# Out:
#                                          Judul Berita  \
# 0        Model Panas Ini Ungkap Ajakan Mesum Neymar 😮
# 1   Kvaratskhelia CINTA Madrid, Mungkinkah Napoli ...
# 2   Bertahan Di PSG, Balik Ke Barcelona Atau Pulan...
# 3   Martinez Diincar United,  Emery: Dia Bakal Ber...
# 4   Soal Eks Striker United, Pelatih JDT: Semua Te...
# 5   Roy Keane Lempar Kritik Menohok Buat Antony, A...
# 6   Jelang El Clasico, Ancelotti: Kontes Vini Jr V...
# 7         Debut Pelatih Persita Perpanjang Derita PSS
# 8   "Jangan Cuma Meledak Dari Bangku Cadangan" - T...
# 9   Jamu Man United, Liverpool Andalkan 'The Power...
# 10  Madrid Bidik Silva Sebagai Alternatif Transfer...
# 11  Elkan Baggott Makin Terpinggirkan Di Cheltenha...
# 12    Madrid Vs Barca: Live Streaming & Kabar Terkini
# 13     Mbappe Dukung Penggalangan Dana Gempa Turki ❤️
# 14        Mane Yakin Klopp Bisa Ubah Nasib Liverpool💪
# 15  Hadapi Timnas U-20, Suriah Siapkan Skema Perma...
# 16  Ultimatum Aneh Xavi Jelang Madrid Vs Barca - P...
# 17  Tae-Yong Tak Ingin Semangat Pemain Timnas U-20...
# 7                                   APA YANG TERJADI?
# 8   APA YANG TERJADI?   Setan Merah tertinggal 1-0...
# 9   Performa apik yang diperlihatkan Manchester Un...
# 10  APA YANG TERJADI? Antonio Silva, berusia 19, m...
# 11  Manajer Cheltenham Town Wade Elliott memastika...
# 12                                         Lompat Ke:
# 13  APA YANG TERJADI? Gempa bumi di Turki dan Suri...
# 14  APA YANG TERJADI? Pemain asal Senegal itu berg...
# 15  Pelatih Suriah Mark Wotte menegaskan, tim besu...
# 16                                 APA YANG TERJADI?
# 17  APA YANG TERJADI? Pelatih timnas Indonesia U-2...
# 18                                  APA YANG TERJADI?
# 19  APA YANG TERJADI? Tim-tim Manchester dipisahka...
# 20  APA YANG TERJADI? Oleksandr Zinchenko memang m...
# 21  Arsenal seperti Leicester City dan tidak akan ...
# 22  Erik ten Hag dilaporkan siap melego tujuh bint...
# 23  APA YANG TERJADI? Luis Enrique dan Zinedine Zi...
# 24  APA YANG TERJADI? Pelatih asal Inggris Sam All...
# 25  APA YANG TERJADI? Arsenal bersiap merombak sku...
# 26  Berbadan besar, berotot dan atletis merupakan ...
# 27                                  APA YANG TERJADI?
# 28  Bakat Marcus Rashford sudah terlihat sejak har...
# 29                                  APA YANG TERJADI?
# 30                                  APA YANG TERJADI?
# 31                                  APA YANG TERJADI?
# 32  Pelatih AS Roma, Jose Mourinho menerima sanksi...
# 33  Striker Real Madrid, Karim Benzema memposting ...
# 34  Pelatih Irak Emad Mohammed sepertinya ingin me...
# 35  Pelatih timnas Indonesia U-20 Shin Tae-yong me...
# 36  Pelatih Jeonnam Dragons Lee Jang-kwan mengaku ...
# 37  APA YANG TERJADI? Manchester City masih berada...
# 38  Dua penggawa timnas Indonesia Jordi Amat dan S...
# 39  APA YANG TERJADI? Casemiro bergabung bersama m...
# 40                                  APA YANG TERJADI?
# 41  Tim nasional junior Indonesia bakal berkompeti...
# 42  Harapan publik sepakbola nasional untuk menyak...
# 43  APA YANG TERJADI?   Pemain internasional Brasi...
# 44  Dunia sepakbola berduka atas meninggalnya lege...
# 45  APA YANG TERJADI?   Performa Virgil van Dijk d...
# 46  APA YANG TERJADI? Graham Potter berada di bawa...
# 47  Setelah puasa gelar selama enam tahun, medioke...
# 48  Musim kompetisi 2022/23 di liga-liga Eropa dim...
# 49  APA YANG TERJADI? PSM Makassar makin tak terbe...
# 50  APA YANG TERJADI?   Rafael Leao saat ini tenga...

# %% [markdown]
# ## 4.Export To CSV

# %%
from google.colab import drive
drive.mount('/content/drive')
path = '/content/drive/My Drive/prosaindata/CrawlingWebBeritaBola.csv'
with open(path, 'w', encoding = 'utf-8-sig') as f:
  data.to_csv(f)
# Out:
# Mounted at /content/drive
