# %% [markdown]
# # CRAWLING TWITTER
# Crawling data twitter tentang Cak Imin menggunakan Snscrape
#
# ---

# %% [markdown]
# ## 1. Install Modul Snscrape

# %%
# !pip install snscrape
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting snscrape
#   Downloading snscrape-0.5.0.20230113-py3-none-any.whl (69 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.2/69.2 KB 4.0 MB/s eta 0:00:00
# Requirement already satisfied: pytz in /usr/local/lib/python3.8/dist-packages (from snscrape) (2022.7.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.8/dist-packages (from snscrape) (4.6.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from snscrape) (3.9.0)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.8/dist-packages (from snscrape) (2.25.1)
# Requirement already satisfied: lxml in /usr/local/lib/python3.8/dist-packages (from snscrape) (4.9.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->snscrape) (2022.12.7)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->snscrape) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->snscrape) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->snscrape) (1.26.14)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->snscrape) (1.7.1)
# Installing collected packages: snscrape
# Successfully installed snscrape-0.5.0.20230113

# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd

# Creating list to append tweet data to
tweets_list2 = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('Cak Imin since:2023-01-01 until:2023-02-28').get_items()):
    if i>500:
        break
    tweets_list2.append([tweet.date, tweet.id, tweet.content, tweet.user.username])
    
# Creating a dataframe from the tweets list above
tweets_df2 = pd.DataFrame(tweets_list2, columns=['Datetime', 'Tweet Id', 'Text', 'Username'])

tweets_df2
# Out:
# <ipython-input-2-949488f39198>:11: FutureWarning: content is deprecated, use rawContent instead
#   tweets_list2.append([tweet.date, tweet.id, tweet.content, tweet.user.username])
#                      Datetime             Tweet Id  \
# 0   2023-02-27 23:56:59+00:00  1630356353423388673
# 1   2023-02-27 22:55:01+00:00  1630340759172923394
# 2   2023-02-27 16:48:07+00:00  1630248424451997697
# 3   2023-02-27 16:37:51+00:00  1630245841163395072
# 4   2023-02-27 16:29:34+00:00  1630243756774391810
# ..                        ...                  ...
# 496 2023-02-22 14:16:42+00:00  1628398379691839488
# 497 2023-02-22 14:10:57+00:00  1628396931964887040
# 498 2023-02-22 14:09:56+00:00  1628396676749881344
# 499 2023-02-22 14:09:38+00:00  1628396602095468546
# 500 2023-02-22 14:07:35+00:00  1628396085340434432
#
#                                                   Text         Username
# 0    @Mdy_Asmara1701 Siapapun boleh...\nPokok asal ...     PakdeA12345a
# 1    Koalisi Gerindra-PKB Belum Punya Capres-Cawapr...     WartaEkonomi
# 2    Team GASPOLL (Gus Muhaimin Asik Poll) NTT Raih...      gaspoll2024
# 3    Jika dilihat dari tanda2, 99% pak Jkw akan men...  nyak_ih_meutuah
# 4    #JokowiCakImin #JoinKepri2019 #NasionalisRelig...  ahmadhellishfau
# ..                                                 ...              ...
# 496  Cak Imin Serap Aspirasi Civitas Akademika Univ...      arpan_nudin
# 497  Cak Imin serap Aspirasi civitas Akdemika\n#Bud...  AbdulRa61022691
# 498  Universitas Trunojoyo\nTerbaik \n\nBaca artike...  iqlil79ardabili
# 499  Cak Imin Serap Aspirasi Civitas Akademika Univ...      FhunnaSarah
# 500  #BudalGus \n#muhaiminberangkat@cakimin@halimis...        AminLubai
#
# [501 rows x 4 columns]
